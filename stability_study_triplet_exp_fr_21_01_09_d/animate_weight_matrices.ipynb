# %%
# %matplotlib notebook
from copy import deepcopy as copy
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import scipy.io as sio
import pandas as pd
from tqdm import tqdm
import pickle
from collections import OrderedDict
import os
from scipy.ndimage.interpolation import shift
from functools import reduce
import time

from aux import Generic
from disp import set_font_size, get_spaced_colors
from ntwk import LIFNtwkG
from utils.general import *
from utils.file_io import *

# %% [markdown]
# $$ \frac{d w_{ij}}{dt} = \alpha C_{ij} w_{ij} + \beta (f_{i}^{0} - f_{i}) w_{ij} $$
#
# $$ \frac {\frac{d w_{ij}}{dt}} {w_{ij}} = \alpha (C_{ij} + \gamma (f_{i}^{0} - f_{i})) $$
#
# $$ \frac { d \, log(w_{ij}) }{dt} = \alpha (C_{ij} + \gamma (f_{i}^{0} - f_{i})) $$
#
# Note: fixed points occur when:
#
# $$ C_{ij} =  \gamma (f_{i} - f_{i}^{0}) $$

# %%
def graph_weight_matrix(mat, title, v_max=None, ax=None, cmap='hot'):
    ax.clear()
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(4, 4), tight_layout=True)
    ax.matshow(mat, vmin=0, vmax=v_max if v_max is not None else mat.max(), cmap=cmap) # 'gist_stern'
    ax.set_title(title)
    set_font_size(ax, 14)

# %%
def animate(direc, frame_rate, v_max, cmap='hot'):
    file_names = [f for f in sorted(all_files_from_dir(direc))]
    plt.ion()
    fig, ax = plt.subplots(1, 1, figsize=(6, 6), tight_layout=True)

    for i_f in range(0, len(file_names), frame_rate):
        file = file_names[i_f]
        loaded = sio.loadmat(os.path.join(direc, file))
        graph_weight_matrix(loaded['w_r_e'], f'{i_f}', ax=ax, v_max=v_max, cmap=cmap)
        fig.canvas.draw()
        time.sleep(0.000001)
    
    loaded = sio.loadmat(os.path.join(direc, file_names[-1]))
    graph_weight_matrix(loaded['w_r_e'], f'{len(file_names) - 1}', ax=ax, v_max=v_max, cmap=cmap)
    w_r = loaded['w_r_e']

# %%
animate('./data/2021-01-11--02:47--59_0_0', 2, 0.26 * 0.004 * .32 / 5, cmap='hot')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
animate('./data/2021-01-11--04:14--27_0_0', 2, 0.26 * 0.004 * .32 / 5, cmap='hot')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
animate('./data/2021-01-11--06:00--58_0_0', 2, 0.26 * 0.004 * .32 / 5, cmap='hot')
# Out:
# <img src="data:image/png;base64,..." width="600">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-3ac1226e0e4a> in <module>
# ----> 1 animate('./data/2021-01-11--06:00--58_0_0', 2, 0.26 * 0.004 * .32 / 5, cmap='hot')
#
# <ipython-input-4-0902cdcec75d> in animate(direc, frame_rate, v_max, cmap)
#       7         file = file_names[i_f]
#       8         loaded = sio.loadmat(os.path.join(direc, file))
# ----> 9         graph_weight_matrix(loaded['w_r_e'], f'{i_f}', ax=ax, v_max=v_max, cmap=cmap)
#      10         fig.canvas.draw()
#      11         time.sleep(0.000001)
#
# <ipython-input-3-fe941628461a> in graph_weight_matrix(mat, title, v_max, ax, cmap)
#       1 def graph_weight_matrix(mat, title, v_max=None, ax=None, cmap='hot'):
# ----> 2     ax.clear()
#       3     if ax is None:
#       4         fig, ax = plt.subplots(1, 1, figsize=(4, 4), tight_layout=True)
#       5     ax.matshow(mat, vmin=0, vmax=v_max if v_max is not None else mat.max(), cmap=cmap) # 'gist_stern'
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in clear(self)
#    1094     def clear(self):
#    1095         """Clear the axes."""
# -> 1096         self.cla()
#    1097
#    1098     def get_facecolor(self):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#     963
#     964         for name, spine in self.spines.items():
# --> 965             spine.cla()
#     966
#     967         self.ignore_existing_data_limits = True
#
# /usr/local/lib/python3.7/site-packages/matplotlib/spines.py in cla(self)
#     240         self._position = None  # clear position
#     241         if self.axis is not None:
# --> 242             self.axis.cla()
#     243
#     244     @cbook.deprecated("3.1")
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in cla(self)
#     855                              rcParams['axes.grid.which'] in ('both', 'minor'))
#     856
# --> 857         self.reset_ticks()
#     858
#     859         self.converter = None
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in reset_ticks(self)
#     878             pass
#     879         try:
# --> 880             self.set_clip_path(self.axes.patch)
#     881         except AttributeError:
#     882             pass
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     967     def set_clip_path(self, clippath, transform=None):
#     968         martist.Artist.set_clip_path(self, clippath, transform)
# --> 969         for child in self.majorTicks + self.minorTicks:
#     970             child.set_clip_path(clippath, transform)
#     971         self.stale = True
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     696             if self._major:
#     697                 instance.majorTicks = []
# --> 698                 tick = instance._get_tick(major=True)
#     699                 instance.majorTicks.append(tick)
#     700                 return instance.majorTicks
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1941         else:
#    1942             tick_kw = self._minor_tick_kw
# -> 1943         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1944
#    1945     def _get_label(self):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     158         self.tick2line = self._get_tick2line()
#     159         self.gridline = self._get_gridline()
# --> 160         self.label1 = self._get_text1()
#     161         self.label2 = self._get_text2()
#     162
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in _get_text1(self)
#     436             color=self._labelcolor,
#     437             verticalalignment=vert,
# --> 438             horizontalalignment=horiz,
#     439             )
#     440         t.set_transform(trans)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     165             linespacing = 1.2   # Maybe use rcParam later.
#     166         self._linespacing = linespacing
# --> 167         self.set_rotation_mode(rotation_mode)
#     168         self.update(kwargs)
#     169
#
# KeyboardInterrupt:

# %%
animate('./data/2021-01-11--07:47--18_0_0', 5, 0.26 * 0.004 * .32 / 5, cmap='hot')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# exp fr set point = 1
animate('./data/2021-01-10--17:42--53_0_0', 1, 0.26 * 0.004 * .32 / 5, cmap='hot')
# Out:
# <img src="data:image/png;base64,..." width="600">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d111912f0f05> in <module>
#       1 # exp fr set point = 1
# ----> 2 animate('./data/2021-01-10--17:42--53_0_0', 1, 0.26 * 0.004 * .32 / 5, cmap='hot')
#
# <ipython-input-4-0902cdcec75d> in animate(direc, frame_rate, v_max, cmap)
#       7         file = file_names[i_f]
#       8         loaded = sio.loadmat(os.path.join(direc, file))
# ----> 9         graph_weight_matrix(loaded['w_r_e'], f'{i_f}', ax=ax, v_max=v_max, cmap=cmap)
#      10         fig.canvas.draw()
#      11         time.sleep(0.000001)
#
# <ipython-input-3-fe941628461a> in graph_weight_matrix(mat, title, v_max, ax, cmap)
#       5     ax.matshow(mat, vmin=0, vmax=v_max if v_max is not None else mat.max(), cmap=cmap) # 'gist_stern'
#       6     ax.set_title(title)
# ----> 7     set_font_size(ax, 14)
#
# ~/work/compneuro/synfire_chain_growth/stability_study_triplet_exp_fr_21_01_09_b/disp.py in set_font_size(ax, font_size, legend_font_size)
#      13
#      14     texts = [ax.title, ax.xaxis.label, ax.yaxis.label] + \
# ---> 15         ax.get_xticklabels() + ax.get_yticklabels()
#      16
#      17     for text in texts:
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in get_xticklabels(self, minor, which)
#    3350            List of `~matplotlib.text.Text` instances.
#    3351         """
# -> 3352         return self.xaxis.get_ticklabels(minor=minor, which=which)
#    3353
#    3354     def set_xticklabels(self, labels, fontdict=None, minor=False, **kwargs):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1318         if minor:
#    1319             return self.get_minorticklabels()
# -> 1320         return self.get_majorticklabels()
#    1321
#    1322     def get_majorticklines(self):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1274     def get_majorticklabels(self):
#    1275         'Return a list of Text instances for the major ticklabels.'
# -> 1276         ticks = self.get_major_ticks()
#    1277         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1278         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1433         while len(self.majorTicks) < numticks:
#    1434             # Update the new tick label properties from the old.
# -> 1435             tick = self._get_tick(major=True)
#    1436             self.majorTicks.append(tick)
#    1437             tick.gridline.set_visible(self._gridOnMajor)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1941         else:
#    1942             tick_kw = self._minor_tick_kw
# -> 1943         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1944
#    1945     def _get_label(self):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157         self.tick1line = self._get_tick1line()
#     158         self.tick2line = self._get_tick2line()
# --> 159         self.gridline = self._get_gridline()
#     160         self.label1 = self._get_text1()
#     161         self.label2 = self._get_text2()
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in _get_gridline(self)
#     492                           alpha=self._grid_alpha,
#     493                           markersize=0,
# --> 494                           **self._grid_kw)
#     495         l.set_transform(self.axes.get_xaxis_transform(which='grid'))
#     496         l.get_path()._interpolation_steps = GRIDLINE_INTERPOLATION_STEPS
#
# /usr/local/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     370         self._us_dashOffset = 0
#     371
# --> 372         self.set_linewidth(linewidth)
#     373         self.set_linestyle(linestyle)
#     374         self.set_drawstyle(drawstyle)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/lines.py in set_linewidth(self, w)
#    1110         # rescale the dashes + offset
#    1111         self._dashOffset, self._dashSeq = _scale_dashes(
# -> 1112             self._us_dashOffset, self._us_dashSeq, self._linewidth)
#    1113
#    1114     def _split_drawstyle_linestyle(self, ls):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/lines.py in _scale_dashes(offset, dashes, lw)
#      58
#      59 def _scale_dashes(offset, dashes, lw):
# ---> 60     if not rcParams['lines.scale_dashes']:
#      61         return offset, dashes
#      62
#
# KeyboardInterrupt:
